# %% [markdown]
# <a href="https://colab.research.google.com/github/seunga2590/Machine-Learning/blob/main/Busan_industrial(shuffled_x)_3%EB%85%84_VOCs_ipynb_(real).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## VOCs

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9114199910679972282
# xla_global_id: -1
# ]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import glob

#vocs_2019 = pd.DataFrame()
#for f in glob.glob('/home/saan/2022_1/vocs/voc_2019/voc_*.xlsx'): 
#    df = pd.read_excel(f)
#    vocs_2019 = vocs_2019.append(df, ignore_index=True)

# %%
#vocs_2020 = pd.DataFrame()
#for f in glob.glob('/home/saan/2022_1/vocs/voc_2020/voc_*.xlsx'): 
#    df = pd.read_excel(f)
#    vocs_2020 = vocs_2020.append(df, ignore_index=True)

# %%
#vocs_2021 = pd.DataFrame()
#for f in glob.glob('/home/saan/2022_1/vocs/voc_2021/voc_*.xlsx'): 
#    df = pd.read_excel(f)
#    vocs_2021 = vocs_2021.append(df, ignore_index=True)

# %%
#VOCs 데이터 불러오기
vocs_2019 = pd.read_excel('/content/drive/My Drive/busan_traffic_/voc_2019.xlsx')
vocs_2020 = pd.read_excel('/content/drive/My Drive/busan_traffic_/voc_2020.xlsx')
vocs_2021 = pd.read_excel('/content/drive/My Drive/busan_traffic_/voc_2021.xlsx')

#vocs 데이터 중 사용할 데이터만 선택
vocs_2019 = vocs_2019[['월','일','암모니아\n(ppb)','톨루엔\n(ppb)','mp-자일렌(ppb)', 
                       'o-자일렌(ppb)','자일렌(ppb)','메틸에틸케톤(ppb)','벤젠(ppb)']]
vocs_2020 = vocs_2020[['월','일','암모니아\n(ppb)','톨루엔\n(ppb)','mp-자일렌(ppb)', 
                       'o-자일렌(ppb)','자일렌(ppb)','메틸에틸케톤(ppb)','벤젠(ppb)']]
vocs_2021 = vocs_2021[['월','일','암모니아\n(ppb)','톨루엔\n(ppb)','mp-자일렌(ppb)', 
                       'o-자일렌(ppb)','자일렌(ppb)','메틸에틸케톤(ppb)','벤젠(ppb)']]

# %%
vocs = pd.concat([vocs_2019, vocs_2020])
vocs = pd.concat([vocs, vocs_2021])
vocs.shape
# Out:
# (26304, 9)

# %%
import numpy as np

vocs['벤젠(ppb)'] = vocs['벤젠(ppb)'].replace('동불', np.nan)
vocs['벤젠(ppb)'] = vocs['벤젠(ppb)'].replace('점검', np.nan)
vocs['벤젠(ppb)'] = vocs['벤젠(ppb)'].replace('동작불가', np.nan)
vocs['벤젠(ppb)'] = vocs['벤젠(ppb)'].replace('전원단절', np.nan)
vocs['벤젠(ppb)'] = vocs['벤젠(ppb)'].replace('전단', np.nan)
vocs['벤젠(ppb)'] = vocs['벤젠(ppb)'].replace('가중', np.nan)

vocs['암모니아\n(ppb)'] = vocs['암모니아\n(ppb)'].replace('동불', np.nan)
vocs['암모니아\n(ppb)'] = vocs['암모니아\n(ppb)'].replace('점검', np.nan)
vocs['암모니아\n(ppb)'] = vocs['암모니아\n(ppb)'].replace('동작불가', np.nan)
vocs['암모니아\n(ppb)'] = vocs['암모니아\n(ppb)'].replace('전원단절', np.nan)
vocs['암모니아\n(ppb)'] = vocs['암모니아\n(ppb)'].replace('전단', np.nan)
vocs['암모니아\n(ppb)'] = vocs['암모니아\n(ppb)'].replace('가중', np.nan)


vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('동불', np.nan)
vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('점검', np.nan)
vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('동작불가', np.nan)
vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('전원단절', np.nan)
vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('전단', np.nan)
vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('가중', np.nan)
vocs['mp-자일렌(ppb)'] = vocs['mp-자일렌(ppb)'].replace('dks ehl', np.nan)


vocs['o-자일렌(ppb)'] = vocs['o-자일렌(ppb)'].replace('동불', np.nan)
vocs['o-자일렌(ppb)'] = vocs['o-자일렌(ppb)'].replace('점검', np.nan)
vocs['o-자일렌(ppb)'] = vocs['o-자일렌(ppb)'].replace('동작불가', np.nan)
vocs['o-자일렌(ppb)'] = vocs['o-자일렌(ppb)'].replace('전원단절', np.nan)
vocs['o-자일렌(ppb)'] = vocs['o-자일렌(ppb)'].replace('전단', np.nan)
vocs['o-자일렌(ppb)'] = vocs['o-자일렌(ppb)'].replace('가중', np.nan)

vocs['톨루엔\n(ppb)'] = vocs['톨루엔\n(ppb)'].replace('동불', np.nan)
vocs['톨루엔\n(ppb)'] = vocs['톨루엔\n(ppb)'].replace('점검', np.nan)
vocs['톨루엔\n(ppb)'] = vocs['톨루엔\n(ppb)'].replace('동작불가', np.nan)
vocs['톨루엔\n(ppb)'] = vocs['톨루엔\n(ppb)'].replace('전원단절', np.nan)
vocs['톨루엔\n(ppb)'] = vocs['톨루엔\n(ppb)'].replace('전단', np.nan)
vocs['톨루엔\n(ppb)'] = vocs['톨루엔\n(ppb)'].replace('가중', np.nan)

vocs['자일렌(ppb)'] = vocs['자일렌(ppb)'].replace('동불', np.nan)
vocs['자일렌(ppb)'] = vocs['자일렌(ppb)'].replace('점검', np.nan)
vocs['자일렌(ppb)'] = vocs['자일렌(ppb)'].replace('동작불가', np.nan)
vocs['자일렌(ppb)'] = vocs['자일렌(ppb)'].replace('전원단절', np.nan)
vocs['자일렌(ppb)'] = vocs['자일렌(ppb)'].replace('전단', np.nan)
vocs['자일렌(ppb)'] = vocs['자일렌(ppb)'].replace('가중', np.nan)

vocs['메틸에틸케톤(ppb)'] = vocs['메틸에틸케톤(ppb)'].replace('동불', np.nan)
vocs['메틸에틸케톤(ppb)'] = vocs['메틸에틸케톤(ppb)'].replace('점검', np.nan)
vocs['메틸에틸케톤(ppb)'] = vocs['메틸에틸케톤(ppb)'].replace('동작불가', np.nan)
vocs['메틸에틸케톤(ppb)'] = vocs['메틸에틸케톤(ppb)'].replace('전원단절', np.nan)
vocs['메틸에틸케톤(ppb)'] = vocs['메틸에틸케톤(ppb)'].replace('전단', np.nan)
vocs['메틸에틸케톤(ppb)'] = vocs['메틸에틸케톤(ppb)'].replace('가중', np.nan)

# %%
vocs.isnull().sum()
# Out:
# 월                 0
# 일                 0
# 암모니아\n(ppb)    1107
# 톨루엔\n(ppb)     1334
# mp-자일렌(ppb)    1333
# o-자일렌(ppb)     1333
# 자일렌(ppb)       1332
# 메틸에틸케톤(ppb)    1332
# 벤젠(ppb)        2155
# dtype: int64

# %%
vocs = vocs.reset_index()

# %%
vocs
# Out:
#        index   월   일  암모니아\n(ppb)  톨루엔\n(ppb)  mp-자일렌(ppb)  o-자일렌(ppb)  \
# 0          0   1   1       76.100       2.800        0.800       0.300
# 1          1   1   1       72.500       2.600        0.500       0.200
# 2          2   1   1       70.100       2.500        0.500       0.200
# 3          3   1   1       67.500       2.500        0.500       0.200
# 4          4   1   1       68.800       1.500        0.400       0.100
# ...      ...  ..  ..          ...         ...          ...         ...
# 26299   8755  12  31       11.157       0.840        0.768       0.240
# 26300   8756  12  31       11.448       6.626        3.246       0.862
# 26301   8757  12  31       10.654       4.612        2.373       0.694
# 26302   8758  12  31       10.940      12.346        7.197       1.826
# 26303   8759  12  31       10.182       1.700        1.332       0.390
#
#        자일렌(ppb)  메틸에틸케톤(ppb)  벤젠(ppb)
# 0         1.100          0.0    0.400
# ...

# %% [markdown]
# ## ASOS

# %%
# ASOS DATA (Busan) 기상데이터

all_data = pd.DataFrame()
for f in glob.glob('/content/drive/My Drive/busan_traffic_/OBS_BUSAN_*.xlsx'):
    df = pd.read_excel(f)
    all_data = all_data.append(df, ignore_index=True)

all_data.head()
# Out:
#     지점 지점명                  일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0  152  울산 2016-01-01 00:00:00     1.7      NaN      1.4     320.0   62.0
# 1  152  울산 2016-01-01 01:00:00     0.4      NaN      1.4     290.0   69.0
# 2  152  울산 2016-01-01 02:00:00    -0.1      NaN      1.1     270.0   71.0
# 3  152  울산 2016-01-01 03:00:00     0.0      NaN      1.4     320.0   69.0
# 4  152  울산 2016-01-01 04:00:00    -0.7      NaN      1.3     290.0   74.0
#
#    증기압(hPa)  이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  전운량(10분위)  \
# 0       4.3       -4.8     1028.0     1032.4     NaN        NaN        0.0
# 1       4.3       -4.6     1027.7     1032.1     NaN        NaN        NaN
# 2       4.3       -4.7     1027.6     1032.0     NaN        NaN        NaN
# 3       4.2       -5.0     1027.5     1031.9     NaN        NaN        0.0
# 4       4.3       -4.7     1027.5     1031.9     NaN        NaN        0.0
#
#    중하층운량(10분위)  최저운고(100m )  시정(10m)
# ...

# %%
# AIR DATA (BUSAN 2016-2020)
air = pd.read_excel('/content/drive/My Drive/busan_traffic_/busan_industrial.xlsx', index_col=0)

# %%
air = air.drop(['CO','PM10'], axis=1)

# %%
# AIR DATA (BUSAN 2021)
air_2021 = pd.DataFrame()
for f in glob.glob('/content/drive/My Drive/busan_industrial/2021_*.xlsx'): 
    df = pd.read_excel(f)
    air_2021 = air_2021.append(df, ignore_index=True)

air_2021
# Out:
#                  날짜  PM10  PM2.5    오 존  이산화질소  일산화탄소  아황산가스
# 0          01-01-01  17.0   16.0  0.023  0.010    0.4  0.002
# 1          01-01-02  19.0   17.0  0.019  0.012    1.0  0.003
# 2          01-01-03  31.0   27.0  0.022  0.009    2.1  0.003
# 3          01-01-04  25.0   22.0  0.022  0.009    3.4  0.009
# 4          01-01-05  38.0   33.0  0.017  0.014    0.5  0.017
# ...             ...   ...    ...    ...    ...    ...    ...
# 8755  2021-11-01:05  23.0   22.0  0.013  0.023    0.4  0.002
# 8756  2021-11-01:04  27.0   17.0  0.015  0.020    0.4  0.002
# 8757  2021-11-01:03  26.0   25.0  0.012  0.023    0.4  0.002
# 8758  2021-11-01:02  30.0   18.0  0.013  0.026    0.4  0.002
# 8759  2021-11-01:01  29.0   24.0  0.009  0.033    0.4  0.002
#
# [8760 rows x 7 columns]

# %%
air_2021 = air_2021.sort_values(by='날짜')

# %%
air_2021 = air_2021.drop(['일산화탄소','PM10'], axis=1)
air_2021.columns = ['date','PM25','O3','NO2','SO2']

# %%
air.columns = ['date','SO2','O3','NO2','PM25']
air = air[['date','PM25','O3','NO2','SO2']]

# %%
air_data = pd.concat([air, air_2021])
air_data = air_data[26304:]
air_data = air_data.reset_index()
air_data = air_data.drop('index', axis=1)

# %%
tomm_pm = air_data['PM25'][24:]
tomm_pm = tomm_pm.reset_index()
air_data['tomm_pm'] = tomm_pm['PM25']
air_data
# Out:
#                 date  PM25     O3    NO2    SO2  tomm_pm
# 0         2019010101  28.0  0.010  0.029  0.003     23.0
# 1         2019010102  23.0  0.013  0.024  0.003     24.0
# 2         2019010103  22.0  0.013  0.024  0.003     25.0
# 3         2019010104  26.0  0.011  0.026  0.003     35.0
# 4         2019010105  29.0  0.014  0.024  0.003     20.0
# ...              ...   ...    ...    ...    ...      ...
# 26299  2021-12-31:20   9.0  0.023  0.019  0.003      NaN
# 26300  2021-12-31:21  12.0  0.023  0.018  0.004      NaN
# 26301  2021-12-31:22  17.0  0.028  0.013  0.003      NaN
# 26302  2021-12-31:23  19.0  0.029  0.012  0.003      NaN
# 26303  2021-12-31:24  15.0  0.028  0.011  0.003      NaN
#
# [26304 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

air_no = air_data[['date','NO2']]
plt.plot(air_data['NO2'])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ###### ASOS DATA

# %%
asos_data = all_data.sort_values(by='일시')

asos_data = asos_data[asos_data['지점명'] == '부산']

asos_data = asos_data.drop(['지점','지점명','최저운고(100m )','해면기압(hPa)','일조(hr)','일사(MJ/m2)','중하층운량(10분위)','시정(10m)'], axis=1)

asos_data['강수량(mm)'] = asos_data['강수량(mm)'].fillna(0)
asos_data['전운량(10분위)'] = asos_data['전운량(10분위)'].fillna(0)

asos_data.columns = ['date','tem','rain','ws','wd','hum','vapor','dew','press','cloud']

# %%
# wind_speed / wind_direction convert to vector
import numpy as np

wv = asos_data.pop('ws')
wd_rad = asos_data.pop('wd')*np.pi / 180

asos_data['wind_x'] = wv*np.cos(wd_rad)
asos_data['wind_y'] = wv*np.sin(wd_rad)

asos_data = asos_data.interpolate(method = 'ffill')

# %%
# Designate date (3 years)
asos_data = asos_data[26304:]
asos_data = asos_data.reset_index()

# %% [markdown]
# ###### Air data

# %%
#air_2021.drop(outliers.index)

# %%
#from collections import Counter 
#def detect_outliers(df, n, features):
#    outlier_indices = [] 
#    for col in features: 
#        Q1 = np.percentile(df[col], 25) 
#        Q3 = np.percentile(df[col], 75) 
#        IQR = Q3 - Q1 
#        outlier_step = 1.5 * IQR 
#        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index 
#        outlier_indices.extend(outlier_list_col) 
#        outlier_indices = Counter(outlier_indices) 
#        multiple_outliers = list(k for k, v in outlier_indices.items() if v > n) 
#        return multiple_outliers

# %%
vocs.columns
# Out:
# Index(['index', '월', '일', '암모니아\n(ppb)', '톨루엔\n(ppb)', 'mp-자일렌(ppb)',
#        'o-자일렌(ppb)', '자일렌(ppb)', '메틸에틸케톤(ppb)', '벤젠(ppb)'],
#       dtype='object')

# %%
vocs.columns = ['index','month','date','ammonia','toluen','mp-xylen','o-xylen','xylen','methyle','benzene']

# %%
air_data['date']    = asos_data['date']
air_data['tem']     = asos_data['tem']
air_data['rain']    = asos_data['rain']
air_data['wind_x']  = asos_data['wind_x']
air_data['wind_y']  = asos_data['wind_y']
air_data['hum']     = asos_data['hum']
air_data['press']   = asos_data['press']
air_data['cloud']   = asos_data['cloud']
air_data['ammonia'] = vocs['ammonia']
air_data['toluen']  = vocs['toluen']
air_data['methyle'] = vocs['methyle']

# %%
air_data.head(3)
# Out:
#                  date  PM25     O3    NO2    SO2  tomm_pm  tem  rain  \
# 0 2019-01-01 00:00:00  28.0  0.010  0.029  0.003     23.0  2.1   0.0
# 1 2019-01-01 01:00:00  23.0  0.013  0.024  0.003     24.0  1.0   0.0
# 2 2019-01-01 02:00:00  22.0  0.013  0.024  0.003     25.0 -0.1   0.0
#
#      wind_x    wind_y   hum   press  cloud  ammonia  toluen  methyle
# 0  1.778505 -4.886402  25.0  1022.5    3.0     76.1     2.8      0.0
# 1  1.641697 -4.510525  25.0  1022.8    0.0     72.5     2.6      0.0
# 2  3.753618 -3.149659  26.0  1022.3    0.0     70.1     2.5      0.0

# %%
#air_data = air_data.drop('index', axis=1)

# %%
#Delete Air data's outlier
#final_air = final_air.drop(outliers.index)
#final_air = final_air.drop(['index', '측정일시'], axis=1)
#final_air = final_air.drop(outliers.index)
print(np.std(air_data['PM25']))
air_data = air_data.set_index('date')
# Out:
# 14.21609332406672

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))

heat_map = air_data.corr()
mask = np.zeros_like(heat_map)
mask[np.triu_indices_from(mask)] =True
heatmap_ax = sns.heatmap(heat_map, annot=True, mask=mask, cmap='coolwarm')
heatmap_ax.set_xticklabels(heatmap_ax.get_xticklabels(), fontsize=12, rotation=45)
heatmap_ax.set_yticklabels(heatmap_ax.get_yticklabels(), fontsize=12)
plt.title('correlation between features')
plt.show()

# %%
graph_data = air_data.reset_index()

# %%
air_data
# Out:
#                      PM25     O3    NO2    SO2  tomm_pm  tem  rain    wind_x  \
# date
# 2019-01-01 00:00:00  28.0  0.010  0.029  0.003     23.0  2.1   0.0  1.778505
# 2019-01-01 01:00:00  23.0  0.013  0.024  0.003     24.0  1.0   0.0  1.641697
# 2019-01-01 02:00:00  22.0  0.013  0.024  0.003     25.0 -0.1   0.0  3.753618
# 2019-01-01 03:00:00  26.0  0.011  0.026  0.003     35.0 -0.9   0.0  3.476863
# 2019-01-01 04:00:00  29.0  0.014  0.024  0.003     20.0 -1.2   0.0  4.416555
# ...                   ...    ...    ...    ...      ...  ...   ...       ...
# 2021-12-31 19:00:00   9.0  0.023  0.019  0.003      NaN  0.5   0.0  1.532089
# 2021-12-31 20:00:00  12.0  0.023  0.018  0.004      NaN  0.0   0.0  1.685298
# 2021-12-31 21:00:00  17.0  0.028  0.013  0.003      NaN -0.4   0.0  1.402283
# 2021-12-31 22:00:00  19.0  0.029  0.012  0.003      NaN -0.8   0.0 -1.094464
# 2021-12-31 23:00:00  15.0  0.028  0.011  0.003      NaN -1.3   0.0  3.370596
#
# ...

# %%
graph_data.dtypes
# Out:
# date       datetime64[ns]
# PM25              float64
# O3                float64
# NO2               float64
# SO2               float64
# tomm_pm           float64
# tem               float64
# rain              float64
# wind_x            float64
# wind_y            float64
# hum               float64
# press             float64
# cloud             float64
# ammonia           float64
# toluen            float64
# methyle           float64
# dtype: object

# %%
plt.plot(air_data['PM25'])

# %%
plt.plot(graph_data['press'])

# %%
plt.plot(graph_data['PM25'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pm_air = graph_data[['date','PM25']]
date = pm_air.date.astype(str).str[0:7]
pm_air['daily_date'] = date
pm_air.head(3)

pm_air['daily_date'] = pd.to_datetime(pm_air['daily_date'])

plt.figure(figsize=(7, 5))
plt.ylim(0, 42)
pm_graph = sns.lineplot(data = pm_air, x='daily_date',y = 'PM25', color = 'palevioletred')
pm_graph.set_facecolor('w')
pm_graph.set_title('Industrial area')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Industrial area')

# %% [markdown]
# ###### DATA

# %%
#x = final_air
#y = final_air['PM25']

#x = np.array(x)
#y = np.array(y)

# %%
#Data shuffle
#from sklearn.model_selection import train_test_split#
#
#air_train, air_test, y_train, y_test = train_test_split(x, y, test_size=0.4, shuffle=True, random_state = 42)
#air_valid, air_test, y_valid, y_test = train_test_split(air_test, y_test, test_size = 0.5, shuffle=True, random_state = 42)#

#air_train = pd.DataFrame(air_train)
#air_valid = pd.DataFrame(air_valid)
#air_test = pd.DataFrame(air_test)

# %%
# Train, Vlidation, test set
air_data = air_data.reset_index()
air_train = air_data[air_data['date'].astype(str).str[:4] == '2019']
air_valid = air_data[air_data['date'].astype(str).str[:4] == '2020']
air_test = air_data[air_data['date'].astype(str).str[:4] == '2021']

#air_train = air_train.drop('index', axis=1)
#air_valid = air_valid.drop('index', axis=1)
#air_test = air_test.drop('index', axis=1)
air_train.shape, air_valid.shape, air_test.shape
# Out:
# ((8760, 16), (8784, 16), (8760, 16))

# %%
air_train.isnull().sum()
# Out:
# date         0
# PM25        58
# O3         141
# NO2        139
# SO2        104
# tomm_pm     58
# tem          0
# rain         0
# wind_x       0
# wind_y       0
# hum          0
# press        0
# cloud        0
# ammonia    175
# toluen     603
# methyle    603
# dtype: int64

# %%
air_train.columns = ['date', 'PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
       'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle']
air_valid.columns = ['date', 'PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
       'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle']
air_test.columns = ['date', 'PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
       'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle']

air_train.shape, air_valid.shape, air_test.shape
# Out:
# ((8760, 16), (8784, 16), (8760, 16))

# %%
#outlier 구하는 식
# 1) 신뢰구간 이용
def outlier(df, col, z):
    return df[abs(df[col] - np.mean(df[col]))/np.std(df[col])>z].index
# 2) IQR (25% 에서 75% 사이의 값 이용하기)
def get_outlier(df=None, column=None, weight = 1.5):
    quantile_25 = np.percentile(df[column].values, 25)
    quantile_75 = np.percentile(df[column].values, 75)
    
    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight
    
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
    
    outlier_idx = df[column][(df[column] < lowest) | (df[column] > highest)].index
    return outlier_idx

# !!!! outlier 구할 때 해당 column에 빈 값이 있으면 결과가 나오지 않음 dropna 이후에 진행하기.

# %%
#결측치 제거
air_train = air_train.dropna(how='any')
air_valid = air_valid.dropna(how='any')
air_test = air_test.dropna(how='any')

air_train = air_train.reset_index()
air_valid = air_valid.reset_index()
air_test = air_test.reset_index()

air_train = air_train.drop('index', axis=1)
air_valid = air_valid.drop('index', axis=1)
air_test = air_test.drop('index', axis=1)

# %%
#def get_outlier(df=None, column=None, weight = 1.5):
outlier_IQR = get_outlier(df = air_test, column='PM25', weight=1.5)
len(outlier_IQR)

air_test = air_test.drop(outlier_IQR)
air_test = air_test.reset_index()
air_test = air_test.drop('index', axis=1)

# %%
x_train = air_train[['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x', 'wind_y',
       'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
y_25_train = air_train[['PM25']]

x_valid = air_valid[['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x', 'wind_y',
       'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
y_25_valid = air_valid[['PM25']]

x_test = air_test[['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x', 'wind_y',
       'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
y_25_test = air_test[['PM25']]

# %%
x_train.apply(pd.to_numeric).head(3)
# Out:
#    PM25     O3    NO2    SO2  tomm_pm  tem  rain    wind_x    wind_y   hum  \
# 0  28.0  0.010  0.029  0.003     23.0  2.1   0.0  1.778505 -4.886402  25.0
# 1  23.0  0.013  0.024  0.003     24.0  1.0   0.0  1.641697 -4.510525  25.0
# 2  22.0  0.013  0.024  0.003     25.0 -0.1   0.0  3.753618 -3.149659  26.0
#
#     press  cloud  ammonia  toluen  methyle
# 0  1022.5    3.0     76.1     2.8      0.0
# 1  1022.8    0.0     72.5     2.6      0.0
# 2  1022.3    0.0     70.1     2.5      0.0

# %%
#StandardScaler & MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() 

scaler.fit(x_train)

train_scaled = pd.DataFrame(scaler.transform(x_train))
valid_scaled = pd.DataFrame(scaler.transform(x_valid))
test_scaled = pd.DataFrame(scaler.transform(x_test))

train_scaled['predict_pm25'] = y_25_train['PM25']
valid_scaled['predict_pm25'] = y_25_valid['PM25']
test_scaled['predict_pm25'] = y_25_test['PM25']

# %%
train_scaled
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.044252 -1.045544  0.481709 -0.850675 -0.286376 -1.706856 -0.143988
# 1    -0.279221 -0.873462  0.074678 -0.850675 -0.222153 -1.843692 -0.143988
# 2    -0.343916 -0.873462  0.074678 -0.850675 -0.157931 -1.980527 -0.143988
# 3    -0.085137 -0.988183  0.237491 -0.850675  0.484293 -2.080044 -0.143988
# 4     0.108946 -0.816101  0.074678 -0.850675 -0.479043 -2.117363 -0.143988
# ...        ...       ...       ...       ...       ...       ...       ...
# 7799  0.820586 -0.873462  0.563116  0.491103 -1.313934 -0.313623 -0.143988
# 7800  0.432419 -0.816101  0.237491  0.043843 -1.249711 -0.263865 -0.143988
# 7801 -0.408610 -0.988183  0.481709  0.043843 -1.057044 -0.313623 -0.143988
# 7802 -0.279221 -1.274986  0.970147  0.043843 -1.185489 -0.288744 -0.143988
# 7803  0.238335 -1.504428  1.458585  0.491103 -1.185489 -0.450458 -0.143988
#
# ...

# %%
x_train.columns
# Out:
# Index(['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
#        'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle'],
#       dtype='object')

# %%
train_scaled.columns = ['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
       'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle', 'predict_pm25']
valid_scaled.columns = ['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
       'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle', 'predict_pm25']
test_scaled.columns = ['PM25', 'O3', 'NO2', 'SO2', 'tomm_pm', 'tem', 'rain', 'wind_x',
       'wind_y', 'hum', 'press', 'cloud', 'ammonia', 'toluen', 'methyle', 'predict_pm25']

train_x = train_scaled[['PM25', 'O3', 'NO2', 'SO2', 'tem', 'rain', 'wind_x', 'wind_y', 'hum',
       'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
train_y = train_scaled[['predict_pm25']]

valid_x = valid_scaled[['PM25', 'O3', 'NO2', 'SO2', 'tem', 'rain', 'wind_x', 'wind_y', 'hum',
       'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
valid_y = valid_scaled[['predict_pm25']]

test_x = test_scaled[['PM25', 'O3', 'NO2', 'SO2', 'tem', 'rain', 'wind_x', 'wind_y', 'hum',
       'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
test_y = test_scaled[['predict_pm25']]

# %%
train_x.shape, valid_x.shape, test_x.shape
# Out:
# ((7804, 14), (7198, 14), (7642, 14))

# %%
train_set = train_x.values
valid_set = valid_x.values
test_set = test_x.values

train_y = train_y.values
valid_y = valid_y.values
test_y = test_y.values

# %%
# data change for LSTM

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index, 24):
    indices = range(i-history_size, i)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 3000
past_history = 24
future_target = 24
STEP = 24

x_train_multi, y_train_multi = multivariate_data(train_set, train_y, 0,
                                                       None, past_history,
                                                       future_target, STEP,
                                                       single_step=False)
x_val_multi, y_val_multi = multivariate_data(valid_set, valid_y,
                                                   0, None, past_history,
                                                   future_target, STEP,
                                                   single_step=False)
x_test_multi, y_test_multi = multivariate_data(test_set, test_y, 0,
                                               None, past_history,
                                               future_target, STEP,
                                               single_step=False)

# %%
x_train_multi.shape
# Out:
# (324, 24, 14)

# %%
# data object to float
x_train_multi = x_train_multi.astype(float)
x_val_multi = x_val_multi.astype(float)
x_test_multi = x_test_multi.astype(float)

y_train_multi = y_train_multi.astype(float)
y_val_multi = y_val_multi.astype(float)
y_test_multi = y_test_multi.astype(float)

# %% [markdown]
# ## DNN MODEL

# %%
dnn_train_x = train_scaled[['PM25', 'O3', 'NO2', 'SO2', 'tem', 'rain', 'wind_x', 'wind_y', 'hum',
       'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
dnn_train_y = x_train[['tomm_pm']]
dnn_valid_x = valid_scaled[['PM25', 'O3', 'NO2', 'SO2', 'tem', 'rain', 'wind_x', 'wind_y', 'hum',
       'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
dnn_valid_y = x_valid[['tomm_pm']]
dnn_test_x = test_scaled[['PM25', 'O3', 'NO2', 'SO2', 'tem', 'rain', 'wind_x', 'wind_y', 'hum',
       'press', 'cloud', 'ammonia', 'toluen', 'methyle']]
dnn_test_y = x_test[['tomm_pm']]

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow import keras
import tensorflow as tf

tf.random.set_seed(0)

dnn_model = tf.keras.models.Sequential()
dnn_model.add(Dense(64,
               input_shape=(dnn_train_x.shape[1],),
               activation='tanh'))
dnn_model.add(Dropout(0.1))
dnn_model.add(Dense(32, activation='relu'))
dnn_model.add(Dense(1))

dnn_model.compile(loss='mse', metrics=['mae'], optimizer=keras.optimizers.Adam(learning_rate=0.01))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow import keras

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01, patience=3, min_lr=0.00001)
checkpoint_cb = keras.callbacks.ModelCheckpoint('dnn.h5')
early_stop = EarlyStopping(monitor='val_loss',patience=200, restore_best_weights=True)

history = dnn_model.fit(dnn_train_x, [dnn_train_y], epochs=10000,
                    validation_data=(dnn_valid_x, [dnn_valid_y]),
                    batch_size=64,
                    callbacks=[early_stop, checkpoint_cb, reduce_lr])

total_loss, main_loss = dnn_model.evaluate(dnn_test_x, [dnn_test_y])
# Out:
# Epoch 1/10000
# 122/122 [==============================] - 2s 6ms/step - loss: 286.8962 - mae: 12.5472 - val_loss: 149.3679 - val_mae: 9.6421 - lr: 0.0100
# Epoch 2/10000
# 122/122 [==============================] - 0s 4ms/step - loss: 168.1784 - mae: 9.7292 - val_loss: 141.5234 - val_mae: 9.1151 - lr: 0.0100
# Epoch 3/10000
# 122/122 [==============================] - 0s 4ms/step - loss: 160.9857 - mae: 9.5134 - val_loss: 148.2540 - val_mae: 9.5584 - lr: 0.0100
# Epoch 4/10000
# 122/122 [==============================] - 1s 4ms/step - loss: 158.0534 - mae: 9.4072 - val_loss: 140.0490 - val_mae: 9.0822 - lr: 0.0100
# Epoch 5/10000
# 122/122 [==============================] - 1s 4ms/step - loss: 153.8883 - mae: 9.2586 - val_loss: 145.8970 - val_mae: 9.3974 - lr: 0.0100
# Epoch 6/10000
# 122/122 [==============================] - 1s 6ms/step - loss: 150.1685 - mae: 9.1353 - val_loss: 151.7346 - val_mae: 9.7727 - lr: 0.0100
# Epoch 7/10000
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
pred = dnn_model.predict([dnn_test_x])
print('Loss', dnn_model.evaluate(dnn_test_x, [dnn_test_y]))
# Out:
# 239/239 [==============================] - 0s 2ms/step - loss: 155.1122 - mae: 8.7542
# Loss [155.11221313476562, 8.75418758392334]

# %%
plt.plot(dnn_test_y)
plt.plot(pred)

# %%
test_10days = dnn_test_x
dnn_10days = pd.DataFrame(dnn_model.predict([test_10days]))

# %%
actual = dnn_test_y
actual = actual.reset_index()
print(actual.columns)
# Out:
# Index(['index', 'tomm_pm'], dtype='object')

# %%
dnn_10days['actual'] = actual['tomm_pm']

# %%
dnn_date = air_test[24:]
dnn_date = dnn_date.reset_index()
dnn_10days['date'] = dnn_date['date']

# %%
dnn_10days['daily'] = dnn_10days['date'].astype(str).str[:10]
dnn_10days['daily'] = pd.to_datetime(dnn_10days['daily'])
dnn_10days = dnn_10days.dropna(how='any')
print(dnn_10days.columns)
# Out:
# Index([0, 'actual', 'date', 'daily'], dtype='object')

# %%
dnn_10days
# Out:
#               0  actual                date      daily
# 0     25.371487    20.0 2021-01-02 00:00:00 2021-01-02
# 1     28.955742    24.0 2021-01-02 01:00:00 2021-01-02
# 2     33.487244    23.0 2021-01-02 02:00:00 2021-01-02
# 3     33.275120    22.0 2021-01-02 03:00:00 2021-01-02
# 4     31.076412    21.0 2021-01-02 04:00:00 2021-01-02
# ...         ...     ...                 ...        ...
# 7613  28.370087    15.0 2021-12-30 19:00:00 2021-12-30
# 7614  25.814804    11.0 2021-12-30 20:00:00 2021-12-30
# 7615  26.321991    16.0 2021-12-30 21:00:00 2021-12-30
# 7616  23.072426    19.0 2021-12-30 22:00:00 2021-12-30
# 7617  23.986450    17.0 2021-12-30 23:00:00 2021-12-30
#
# [7618 rows x 4 columns]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data = dnn_10days[:3500], x = 'daily', y = dnn_10days.actual)
sns.lineplot(data = dnn_10days[:3500], x= 'daily', y = dnn_10days[0])
plt.legend(['prediction', 'actual'])

# %% [markdown]
# ### RNN MODEL (Simple RNN)

# %%
from tensorflow.keras.layers import SimpleRNN

tf.random.set_seed(3)

rnn_model = tf.keras.models.Sequential()
rnn_model.add(SimpleRNN(64,
               input_shape=(x_train_multi.shape[1],x_train_multi.shape[2]),
               activation='tanh'))
rnn_model.add(Dropout(0.1))
rnn_model.add(Dense(32, activation='relu'))
rnn_model.add(Dense(24))

rnn_model.compile(loss='mse', metrics=['mae'], optimizer=keras.optimizers.Adam(learning_rate=0.01))

# %%
#from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow import keras

#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.00001)
checkpoint_cb = keras.callbacks.ModelCheckpoint('lstm.h5', mode='min')
early_stop = EarlyStopping(monitor='val_loss',patience=300, restore_best_weights=True)

history = rnn_model.fit(x_train_multi, [y_train_multi], epochs=10000,
                    validation_data=(x_val_multi, [y_val_multi]),
                    batch_size=6,
                    callbacks=[early_stop,  checkpoint_cb])

total_loss, main_loss = rnn_model.evaluate(x_test_multi, [y_test_multi])
# Out:
# Epoch 1/10000
# 54/54 [==============================] - 2s 13ms/step - loss: 407.6482 - mae: 15.5280 - val_loss: 169.2689 - val_mae: 10.5821
# Epoch 2/10000
# 54/54 [==============================] - 0s 8ms/step - loss: 226.4035 - mae: 11.4623 - val_loss: 179.4925 - val_mae: 10.8880
# Epoch 3/10000
# 54/54 [==============================] - 1s 10ms/step - loss: 235.8755 - mae: 11.5035 - val_loss: 191.1992 - val_mae: 11.7010
# Epoch 4/10000
# 54/54 [==============================] - 1s 11ms/step - loss: 223.9274 - mae: 11.3436 - val_loss: 161.9024 - val_mae: 10.3313
# Epoch 5/10000
# 54/54 [==============================] - 1s 10ms/step - loss: 217.6576 - mae: 10.9916 - val_loss: 155.5569 - val_mae: 10.1244
# Epoch 6/10000
# 54/54 [==============================] - 1s 10ms/step - loss: 218.7327 - mae: 11.1181 - val_loss: 133.3650 - val_mae: 8.8782
# Epoch 7/10000
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
pred = rnn_model.predict([x_test_multi])
print('Loss', rnn_model.evaluate(x_test_multi, [y_test_multi]))
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 79.3523 - mae: 7.1145
# Loss [79.3522720336914, 7.114504337310791]

# %%
pd.DataFrame(rnn_model.predict([x_test_multi]))
# Out:
#             0          1          2          3          4          5   \
# 0    17.424992  17.833828  17.635857  19.065765  18.893436  19.792295
# 1    20.971453  21.058512  20.998407  22.294889  21.661602  22.220238
# 2    22.855957  22.839657  22.684629  23.935324  23.091181  23.437706
# 3    33.398056  33.876038  33.136543  31.731499  32.613827  32.715904
# 4    33.360928  33.841560  33.104851  31.713047  32.588547  32.692337
# ..         ...        ...        ...        ...        ...        ...
# 312  33.399628  33.877674  33.138187  31.732523  32.615341  32.717529
# 313  21.610546  21.662058  21.568600  22.849640  22.144611  22.630575
# 314  17.300867  17.722267  17.516178  18.951248  18.795708  19.705849
# 315  33.397141  33.875191  33.135765  31.731045  32.613205  32.715324
# 316  33.398026  33.876011  33.136520  31.731483  32.613808  32.715889
#
#             6          7          8          9   ...         14         15  \
# ...

# %%
rnn_month_1 = rnn_model.predict(x_test_multi)[:, :1]
rnn_month_df_1 = pd.DataFrame(rnn_month_1)
rnn_month_1.shape
# Out:
# (317, 1)

# %%
# test에 대한 prediction 결과나열
for i in range(1, 24):
    rnn_month_df_1['month_{}'.format(i)] = rnn_model.predict(x_test_multi)[:, i:i+1]

rnn_month_df_2 = rnn_month_df_1.transpose()

# %%
pre = []
def make_df(dataframe):
  dataframe = dataframe
  for i in range(len(dataframe.columns)):
    result = dataframe.iloc[:,i]
    pre.append(result)
    pre1 = pd.concat(pre, ignore_index=True)
  return pre1

# %%
rnn_month_df_3 = make_df(rnn_month_df_2)
rnn_month_df_3
# Out:
# 0       17.424992
# 1       17.833828
# 2       17.635857
# 3       19.065765
# 4       18.893436
#           ...
# 7603    34.172951
# 7604    34.461781
# 7605    34.700256
# 7606    34.464607
# 7607    34.157188
# Length: 7608, dtype: float32

# %%
# prediction 결과의 날짜는 1월 2일부터
rnn_air_date = air_test['date'][24:-24]
rnn_air_date = rnn_air_date.reset_index()
rnn_air_date.head(2)
# Out:
#    index                date
# 0     24 2021-01-02 00:00:00
# 1     25 2021-01-02 01:00:00

# %%
rnn_air_date['value'] = rnn_month_df_3
# 실제 관측값
actual = test_y[24:-24]
rnn_air_date['actual'] = actual

# %%
# 실제 관측값 & 모델 예측값
rnn_air_date
# Out:
#       index                date      value  actual
# 0        24 2021-01-02 00:00:00  17.424992    20.0
# 1        25 2021-01-02 01:00:00  17.833828    24.0
# 2        26 2021-01-02 02:00:00  17.635857    23.0
# 3        27 2021-01-02 03:00:00  19.065765    22.0
# 4        28 2021-01-02 04:00:00  18.893436    21.0
# ...     ...                 ...        ...     ...
# 7589   7613 2021-12-29 19:00:00  32.715889    32.0
# 7590   7614 2021-12-29 20:00:00  32.092045    31.0
# 7591   7615 2021-12-29 21:00:00  31.886068    29.0
# 7592   7616 2021-12-29 22:00:00  31.862335    35.0
# 7593   7617 2021-12-29 23:00:00  32.065285    39.0
#
# [7594 rows x 4 columns]

# %%
rnn_air_date['actual'] = rnn_air_date['actual'].astype(float)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 6))
sns.lineplot(data = rnn_air_date, x=rnn_air_date['date'], y= rnn_air_date['actual'])
sns.lineplot(data = rnn_air_date, x=rnn_air_date['date'], y= rnn_air_date['value'])
plt.legend(['actual','value'])

# %%
#Monthly data
rnn_monthly_date = rnn_air_date['date'].astype(str).str[:7]
rnn_air_date['monthly_date'] = rnn_monthly_date

#hourly data
rnn_time = rnn_air_date['date'].astype(str).str[11:13]
rnn_air_date['hour'] = rnn_time

#daily data
rnn_daily_new_date = rnn_air_date['date'].astype(str).str[:10]
rnn_air_date['daily_new_date'] = rnn_daily_new_date
rnn_air_date['daily_new_date'] = pd.to_datetime(rnn_air_date['daily_new_date'])

# %%
# Monthly graph
plt.figure(figsize=(20, 5))
plt.ylim(5, 30)
plt.grid(False)
sns.set(font_scale = 0.9)

sns.lineplot(data = rnn_air_date, x=rnn_air_date['monthly_date'], y= rnn_air_date['actual'])
sns.lineplot(data = rnn_air_date, x=rnn_air_date['monthly_date'], y= rnn_air_date['value'])
plt.legend(['actual','value'])

# %%
#Hourly graph
plt.figure(figsize=(20, 4))
plt.ylim(10, 25)
plt.grid(False)
sns.set(font_scale = 0.8)

graph = sns.lineplot(data = rnn_air_date, x=rnn_air_date['hour'], y= rnn_air_date['actual'])
graph_2 = sns.lineplot(data = rnn_air_date, x=rnn_air_date['hour'], y= rnn_air_date['value'])
graph.set_xlabel('hour', fontsize = 15)
graph.set_ylabel('PM2.5', fontsize = 15)
plt.legend(labels = ['Actual_value', 'Predicted_lstm'])

# %%
rnn_air_date['dnn'] = dnn_10days[:-24][0]
rnn_air_date.head()
# Out:
#    index                date      value  actual monthly_date hour  \
# 0     24 2021-01-02 00:00:00  17.424992    20.0      2021-01   00
# 1     25 2021-01-02 01:00:00  17.833828    24.0      2021-01   01
# 2     26 2021-01-02 02:00:00  17.635857    23.0      2021-01   02
# 3     27 2021-01-02 03:00:00  19.065765    22.0      2021-01   03
# 4     28 2021-01-02 04:00:00  18.893436    21.0      2021-01   04
#
#   daily_new_date        dnn
# 0     2021-01-02  25.371487
# 1     2021-01-02  28.955742
# 2     2021-01-02  33.487244
# 3     2021-01-02  33.275120
# 4     2021-01-02  31.076412

# %%
rnn_air_date
# Out:
#       index                date      value  actual monthly_date hour  \
# 0        24 2021-01-02 00:00:00  17.424992    20.0      2021-01   00
# 1        25 2021-01-02 01:00:00  17.833828    24.0      2021-01   01
# 2        26 2021-01-02 02:00:00  17.635857    23.0      2021-01   02
# 3        27 2021-01-02 03:00:00  19.065765    22.0      2021-01   03
# 4        28 2021-01-02 04:00:00  18.893436    21.0      2021-01   04
# ...     ...                 ...        ...     ...          ...  ...
# 7589   7613 2021-12-29 19:00:00  32.715889    32.0      2021-12   19
# 7590   7614 2021-12-29 20:00:00  32.092045    31.0      2021-12   20
# 7591   7615 2021-12-29 21:00:00  31.886068    29.0      2021-12   21
# 7592   7616 2021-12-29 22:00:00  31.862335    35.0      2021-12   22
# 7593   7617 2021-12-29 23:00:00  32.065285    39.0      2021-12   23
#
#      daily_new_date        dnn
# 0        2021-01-02  25.371487
# 1        2021-01-02  28.955742
# 2        2021-01-02  33.487244
# ...

# %%
# Daily graph
plt.figure(figsize=(20, 5))
plt.grid(False)

graph = sns.lineplot(data = rnn_air_date, x=rnn_air_date['daily_new_date'][:1000], y= rnn_air_date['actual'][:1000], color = 'r')
graph_2 = sns.lineplot(data = rnn_air_date, x=rnn_air_date['daily_new_date'][:1000], y= rnn_air_date['value'][:1000], color='g')
graph_3 = sns.lineplot(data = rnn_air_date, x=rnn_air_date['daily_new_date'][:1000], y = rnn_air_date['dnn'][:1000], color='b')
graph.set_xlabel('date', fontsize = 15)
graph.set_ylabel('PM2.5', fontsize = 15)
plt.legend(['Actual_value', 'rnn_value', 'dnn'])

# %% [markdown]
# ### LSTM MODEL

# %%
# LSTM
from tensorflow import keras
import tensorflow as tf
print('tf_version:',tf.__version__)
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout

tf.random.set_seed(7)

model = tf.keras.models.Sequential()
model.add(LSTM(64,
               input_shape=(x_train_multi.shape[1], x_train_multi.shape[2]),
               activation='tanh',
               return_sequences=False))
#model.add(LSTM(32, activation='tanh'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dense(24))

model.compile(loss='mse', metrics=['mae'], optimizer=keras.optimizers.Adam(learning_rate=0.01))
# Out:
# tf_version: 2.8.2

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow import keras

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)
checkpoint_cb = keras.callbacks.ModelCheckpoint('lstm.h5', mode='min')
early_stop = EarlyStopping(monitor='val_loss',patience=300, restore_best_weights=True)

history = model.fit(x_train_multi, [y_train_multi], epochs=10000,
                    validation_data=(x_val_multi, [y_val_multi]),
                    batch_size=6,
                    callbacks=[early_stop, reduce_lr, checkpoint_cb])

total_loss, main_loss = model.evaluate(x_test_multi, [y_test_multi])
# Out:
# Epoch 1/10000
# 54/54 [==============================] - 7s 55ms/step - loss: 389.0095 - mae: 14.7635 - val_loss: 138.3573 - val_mae: 8.6398 - lr: 0.0100
# Epoch 2/10000
# 54/54 [==============================] - 2s 36ms/step - loss: 204.1365 - mae: 10.5494 - val_loss: 118.8438 - val_mae: 8.4656 - lr: 0.0100
# Epoch 3/10000
# 54/54 [==============================] - 1s 19ms/step - loss: 178.9505 - mae: 9.9892 - val_loss: 133.7944 - val_mae: 8.6097 - lr: 0.0100
# Epoch 4/10000
# 54/54 [==============================] - 1s 16ms/step - loss: 193.8994 - mae: 10.3050 - val_loss: 186.8018 - val_mae: 10.5951 - lr: 0.0100
# Epoch 5/10000
# 54/54 [==============================] - 1s 18ms/step - loss: 170.9939 - mae: 9.7171 - val_loss: 122.0649 - val_mae: 8.1209 - lr: 0.0100
# Epoch 6/10000
# 54/54 [==============================] - 1s 16ms/step - loss: 168.4722 - mae: 9.6011 - val_loss: 120.4319 - val_mae: 8.0351 - lr: 0.0100
# Epoch 7/10000
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
pred = model.predict([x_test_multi])
print('Loss', model.evaluate(x_test_multi, [y_test_multi]))
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 76.4302 - mae: 7.0093
# Loss [76.43017578125, 7.009296417236328]

# %%
pd.DataFrame(model.predict([x_test_multi]))
# Out:
#             0          1          2          3          4          5   \
# 0    24.036015  23.586388  23.441267  25.523439  24.626480  23.636662
# 1    25.148809  24.644636  24.434210  26.558464  25.682087  24.786596
# 2    27.020996  26.551729  26.228251  28.308153  27.495750  26.638872
# 3    36.173492  36.406242  35.166290  36.166439  35.830448  35.062984
# 4    29.802988  29.670437  28.894491  30.522366  29.961004  29.214884
# ..         ...        ...        ...        ...        ...        ...
# 312  35.080841  35.487381  34.095169  34.886101  34.642826  34.065498
# 313  24.236216  23.706383  23.659105  25.772766  24.844723  23.736256
# 314  28.034367  27.769327  27.340439  29.252741  28.416084  27.287113
# 315  33.089516  33.218014  32.193192  33.429237  32.979500  32.157181
# 316  32.640968  32.726334  31.682894  32.869354  32.485874  31.851164
#
#             6          7          8          9   ...         14         15  \
# ...

# %% [markdown]
# ###### Graph

# %%
month_1 = model.predict(x_test_multi)[:, :1]
month_df_1 = pd.DataFrame(month_1)
month_1.shape
# Out:
# (317, 1)

# %%
# test에 대한 prediction 결과나열
for i in range(1, 24):
    month_df_1['month_{}'.format(i)] = model.predict(x_test_multi)[:, i:i+1]

month_df_2 = month_df_1.transpose()

# %%
pre = []
def make_df(dataframe):
  dataframe = dataframe
  for i in range(len(dataframe.columns)):
    result = dataframe.iloc[:,i]
    pre.append(result)
    pre1 = pd.concat(pre, ignore_index=True)
  return pre1

# %%
month_df_3 = make_df(month_df_2)
month_df_3
# Out:
# 0       24.036015
# 1       23.586388
# 2       23.441267
# 3       25.523439
# 4       24.626480
#           ...
# 7603    30.658836
# 7604    32.834763
# 7605    32.149914
# 7606    32.042259
# 7607    32.085598
# Length: 7608, dtype: float32

# %%
# prediction 결과의 날짜는 1월 2일부터
air_date = air_test['date'][24:-24]
air_date = air_date.reset_index()
air_date.head(2)
# Out:
#    index                date
# 0     24 2021-01-02 00:00:00
# 1     25 2021-01-02 01:00:00

# %%
air_date['value'] = month_df_3
# 실제 관측값
actual = test_y[24:-24]
air_date['actual'] = actual

# %%
# 실제 관측값 & 모델 예측값
air_date
# Out:
#       index                date      value  actual
# 0        24 2021-01-02 00:00:00  24.036015    20.0
# 1        25 2021-01-02 01:00:00  23.586388    24.0
# 2        26 2021-01-02 02:00:00  23.441267    23.0
# 3        27 2021-01-02 03:00:00  25.523439    22.0
# 4        28 2021-01-02 04:00:00  24.626480    21.0
# ...     ...                 ...        ...     ...
# 7589   7613 2021-12-29 19:00:00  31.851164    32.0
# 7590   7614 2021-12-29 20:00:00  31.392155    31.0
# 7591   7615 2021-12-29 21:00:00  31.862083    29.0
# 7592   7616 2021-12-29 22:00:00  31.063078    35.0
# 7593   7617 2021-12-29 23:00:00  33.872864    39.0
#
# [7594 rows x 4 columns]

# %%
air_date['actual'] = air_date['actual'].astype(float)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 6))
sns.lineplot(data = air_date, x=air_date['date'], y= air_date['actual'])
sns.lineplot(data = air_date, x=air_date['date'], y= air_date['value'])
plt.legend(['actual','value'])

# %%
#Monthly data
monthly_date = air_date['date'].astype(str).str[:7]
air_date['monthly_date'] = monthly_date

#hourly data
time = air_date['date'].astype(str).str[11:13]
air_date['hour'] = time

#daily data
daily_new_date = air_date['date'].astype(str).str[:10]
air_date['daily_new_date'] = daily_new_date
air_date['daily_new_date'] = pd.to_datetime(air_date['daily_new_date'])

# %%
# Monthly graph
plt.figure(figsize=(10, 5))
plt.ylim(5, 30)
plt.grid(False)
sns.set(font_scale = 1.0)

sns.lineplot(data = air_date, x=air_date['monthly_date'], y= air_date['actual'], color='g')
sns.lineplot(data = air_date, x=air_date['monthly_date'], y= air_date['value'], color ='b')

plt.legend(['actual','value'])

# %%
#Hourly graph
plt.figure(figsize=(20, 4))
plt.grid(False)
sns.set(font_scale = 0.9)

graph = sns.lineplot(data = air_date, x=air_date['hour'], y= air_date['actual'])
graph_2 = sns.lineplot(data = air_date, x=air_date['hour'], y= air_date['value'])
graph_2 = sns.lineplot(data = rnn_air_date, x=rnn_air_date['hour'], y= rnn_air_date['value'])

graph.set_xlabel('hour', fontsize = 10)
graph.set_ylabel('PM2.5', fontsize = 10)
plt.legend(labels = ['Actual_value', 'Predicted_lstm', 'predict_rnn'])

# %%
# Daily graph
plt.figure(figsize=(25, 4))
plt.grid(False)
sns.set(font_scale = 0.9)

graph = sns.lineplot(data = air_date, x=air_date['daily_new_date'], y= air_date['actual'])
graph_2 = sns.lineplot(data = air_date, x=air_date['daily_new_date'], y= air_date['value'])
graph.set_xlabel('date', fontsize = 15)
graph.set_ylabel('PM2.5', fontsize = 15)
plt.legend(['Actual_value', 'lstm_value'])

# %%
rnn_air_date.columns
# Out:
# Index(['index', 'date', 'value', 'actual', 'monthly_date', 'hour',
#        'daily_new_date', 'dnn'],
#       dtype='object')

# %%
air_date['rnn'] = rnn_air_date['value']
air_date['dnn'] = rnn_air_date['dnn']
air_date.head()
# Out:
#    index                date      value  actual monthly_date hour  \
# 0     24 2021-01-02 00:00:00  24.036015    20.0      2021-01   00
# 1     25 2021-01-02 01:00:00  23.586388    24.0      2021-01   01
# 2     26 2021-01-02 02:00:00  23.441267    23.0      2021-01   02
# 3     27 2021-01-02 03:00:00  25.523439    22.0      2021-01   03
# 4     28 2021-01-02 04:00:00  24.626480    21.0      2021-01   04
#
#   daily_new_date        rnn        dnn
# 0     2021-01-02  17.424992  25.371487
# 1     2021-01-02  17.833828  28.955742
# 2     2021-01-02  17.635857  33.487244
# 3     2021-01-02  19.065765  33.275120
# 4     2021-01-02  18.893436  31.076412

# %%
# Monthly graph
plt.figure(figsize=(20, 5))
plt.ylim(5, 28)
plt.grid(False)
sns.set(font_scale = 1.0)
ax = plt.gca()
ax.set_facecolor('white')
graph.set_xlabel('hour', fontsize = 10)
graph.set_ylabel('PM2.5', fontsize = 10)
sns.lineplot(data = air_date, x=air_date['monthly_date'], y= air_date['actual'], color='red', marker = 'o')
sns.lineplot(data = air_date, x=air_date['monthly_date'], y= air_date['value'], color ='blue', marker = 'o')
sns.lineplot(data = air_date, x = 'monthly_date',y = 'rnn', color = 'g', marker='o')
sns.lineplot(data = air_date, x = 'monthly_date', y = 'dnn',color = 'c', marker = 'o')
plt.legend(['actual','lstm','rnn','dnn'])

# %%
# Daily graph
plt.figure(figsize=(20, 5))
plt.grid(False)
sns.set(font_scale = 0.9)

graph = sns.lineplot(data = air_date, x=air_date['daily_new_date'], y= air_date['actual'])
graph_1 = sns.lineplot(data = air_date, x=air_date['daily_new_date'], y= air_date['dnn'])
graph_2 = sns.lineplot(data = air_date, x = air_date['daily_new_date'], y = air_date['rnn'])
graph_3 = sns.lineplot(data = air_date, x = air_date['daily_new_date'], y = air_date['value'])
graph.set_xlabel('date', fontsize = 15)
graph.set_ylabel('PM2.5', fontsize = 15)
plt.legend(['Actual', 'Dnn_value','Rnn_value','Lstm_value'])

# %% [markdown]
# ## tf_v1 SHAP

# %%
y_train_multi = y_train_multi.reshape(y_train_multi.shape[0], y_train_multi.shape[1])
y_val_multi = y_val_multi.reshape(y_val_multi.shape[0], y_val_multi.shape[1])
y_test_multi = y_test_multi.reshape(y_test_multi.shape[0], y_test_multi.shape[1])

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow import keras

tf.random.set_seed(62) #20

model = tf.keras.models.Sequential()
model.add(LSTM(64,
               input_shape=(x_train_multi.shape[1], x_train_multi.shape[2]),
               activation='tanh'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(24))

model.compile(loss='mse', metrics=['mae'], optimizer=keras.optimizers.Adam(learning_rate=0.01))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow import keras

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01, patience=3, min_lr=0.00001)
checkpoint_cb = keras.callbacks.ModelCheckpoint('lstm.h5', mode='min')
early_stop = EarlyStopping(monitor='val_loss',patience=300, restore_best_weights=True)

history = model.fit(x_train_multi, [y_train_multi], epochs=10000,
                    validation_data=(x_val_multi, [y_val_multi]),
                    batch_size=32,
                    callbacks=[early_stop, reduce_lr, checkpoint_cb])

total_loss, main_loss = model.evaluate(x_test_multi, [y_test_multi])
# Out:
# Train on 324 samples, validate on 298 samples
# Epoch 1/10000
# 256/324 [======================>.......] - ETA: 0s - loss: 920.1781 - mean_absolute_error: 25.7152
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# 324/324 [==============================] - 9s 28ms/sample - loss: 828.9687 - mean_absolute_error: 23.9241 - val_loss: 198.7206 - val_mean_absolute_error: 11.0686 - lr: 0.0100
# Epoch 2/10000
# 324/324 [==============================] - 0s 424us/sample - loss: 281.7044 - mean_absolute_error: 12.8647 - val_loss: 148.9314 - val_mean_absolute_error: 9.0854 - lr: 0.0100
# Epoch 3/10000
# 324/324 [==============================] - 0s 428us/sample - loss: 226.1256 - mean_absolute_error: 10.9179 - val_loss: 148.2355 - val_mean_absolute_error: 9.3387 - lr: 0.0100
# Epoch 4/10000
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
pred = model.predict([x_test_multi])
print('Loss', model.evaluate(x_test_multi, [y_test_multi]))
# Out:
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# Loss [79.21964925772008, 7.0826283]

# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import shap

# %%
x_test_multi.shape
# Out:
# (317, 24, 14)

# %%
shap.initjs()
explainer = shap.DeepExplainer(model, x_train_multi)
shap_values = explainer.shap_values(x_test_multi[:, :, :])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap.dependence_plot('ammonia', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='SO2', feature_names = train_x.columns)

# %%
  #shap를 이용한 Feature importance
plt.grid(False)
ax = plt.gca()
ax.patch.set_facecolor('#FFFFFF')
plt.ylabel('Variables', fontsize=13.5)
plt.title('(b) Feature importance of the industrial area',
          position = (0.325, 1.02), fontsize=13.5)
shap.summary_plot(shap_values[23][:, 23, :], x_test_multi[:, 23, :], plot_type='bar', feature_names = train_x.columns)

# %%
#shap를 이용한 summary plot
plt.grid(False)
ax = plt.gca()
ax.patch.set_facecolor('#FFFFFF')
plt.ylabel('Variables', fontsize=13.5)
plt.title('(b) Feature importance of the industrial area',
          position = (0.40, 1.02), fontsize=14.0)
shap.summary_plot(shap_values[23][:, 23, :], x_test_multi[:, 23, :], feature_names = train_x.columns)

# %%
shap.initjs()
top_inds = np.argsort(-np.sum(np.abs(shap_values[23][:, 23, :]), 0))
for i in range(3):
    shap.dependence_plot(top_inds[i], shap_values[23][:, 23, :], x_test_multi[:, 23, :], feature_names = train_x.columns)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
type(model)
# Out:
# keras.engine.sequential.Sequential

# %% [markdown]
# ###  Dependence plot 원리

# %%
shap.dependence_plot('ammonia', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='SO2', feature_names = train_x.columns)

# %%
shap.dependence_plot('NO2', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='O3', feature_names = train_x.columns)
shap.dependence_plot('ammonia', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='SO2', feature_names = train_x.columns)
shap.dependence_plot('O3', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='PM25', feature_names = train_x.columns)
shap.dependence_plot('NO2', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='PM25', feature_names = train_x.columns)
shap.dependence_plot('hum', shap_values[23][:, 23, :], x_test_multi[:, 23, :], interaction_index='PM25', feature_names = train_x.columns)

# %% [markdown]
# #### SHAP code 분석

# %%
phis = []
for k in range(len(x_test_multi)):
    phis.append(np.zeros(x_test_multi[k].shape))
    
len(model.outputs)
# Out:
# 1

# %%
for j in range(x_test_multi[0].shape[0]):
    if (hasattr(x_train_multi, '__call__')):
        bg_data = x_train_multi([x_test_multi[l][j] for l in range(len(x_test_multi))])
        if type(bg_data) != list:
            bg_data = [bg_data]
    else:
            bg_data = x_train_multi
            
    tiled_X = [np.tile(x_test_multi[l][j:j+1], (bg_data[l].shape[0],)+ tuple([1 for k in range(len(x_test_multi[l].shape)-1)])) for l in range(len(x_test_multi))]
    joint_input = [np.concatenate([tiled_X[l], bg_data[l]], 0) for l in range(len(x_test_multi))]
    
hasattr(x_train_multi, '__call__')
# Out:
# False

# %%
# model output
def __init__(self, model, data, session=None):
    def _get_model_output(self, model):
        if len(model.layers[-1]._inbound_nodes) ==0:
            if len(model.outputs) > 1:
                warnings.warn('Only one model output supported')
            return model.outputs[0]
        else:
            return model.layers[-1].output

# %%
def shap_df(data):
    sh_value = []
    for i in range(len(data[23])):
        data = data
        s_value = pd.DataFrame(data[23][i])
        sh_value.append(s_value)
        s_values = pd.concat(sh_value, ignore_index=True)
    
    return s_values

# %%
shap_df = shap_df(shap_values)

# %%
shap_date = air_test.date[24:-21]
shap_date = shap_date.reset_index()
shap_df['date'] = shap_date['date']
shap_df = shap_df.set_index('date')

s_df = shap_df.reset_index()
s_df = s_df[s_df['date'].astype(str).str[11:13] == '23']
shap_values[23][:, 23, :]
# Out:
# array([[-0.96098939, -0.16592211, -0.97479928, ...,  0.331829  ,
#          0.23756935, -0.13804585],
#        [-1.63768403, -0.05265381, -1.24707282, ...,  0.33053938,
#          0.40773873, -0.13671484],
#        [-1.43786915,  0.04101461, -1.70090665, ...,  0.31072176,
#          0.3733104 , -0.12916101],
#        ...,
#        [-0.12195828, -0.43390592,  0.7096289 , ...,  0.36107283,
#          0.17362523,  0.01777853],
#        [-4.37077999,  0.01671784, -1.57314092, ...,  0.309028  ,
#          0.34167351, -0.11317638],
#        [-1.64490032, -0.2265697 , -0.57778295, ...,  0.34291475,
#          0.02232825, -0.1345671 ]])

# %%
test_date = air_test.drop('tomm_pm', axis=1)
s_df.columns = test_date.columns
s_df = s_df.reset_index()
s_df = s_df.drop('index', axis=1)
s_df.head(2)
# Out:
#                  date      PM25        O3       NO2       SO2       tem  \
# 0 2021-01-02 23:00:00 -0.960989 -0.165922 -0.974799 -0.055930  1.535499
# 1 2021-01-03 23:00:00 -1.637684 -0.052654 -1.247073 -0.064977  1.818782
#
#        rain    wind_x    wind_y       hum     press     cloud   ammonia  \
# 0  0.044124 -0.036688 -0.205036 -0.238518 -0.064993  0.421889  0.331829
# 1  0.042421  0.019288  0.093290 -0.568770  0.020472  0.417336  0.330539
#
#      toluen   methyle
# 0  0.237569 -0.138046
# 1  0.407739 -0.136715

# %%
actual_no = pd.DataFrame(test_scaled['O3'])
actual_no['date'] = air_test['date']
actual_no = actual_no[24:-21]
actual_no = actual_no[actual_no['date'].astype(str).str[11:13] == '23']
actual_no = actual_no.reset_index()
actual_no = actual_no.drop('index', axis=1)

actual_no['shap_O3'] = s_df['O3']
print(len(shap_values[23][:, 23, 1].shape))
actual_no.head(2)
# Out:
# 1
#          O3                date   shap_O3
# 0 -0.176856 2021-01-02 23:00:00 -0.165922
# 1  0.287617 2021-01-03 23:00:00 -0.052654
